# %% [markdown]
# #3. Làm quen với Scatter plot

# %%
#import các thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#bước 2: nạp dữ liệu
df = pd.read_csv("https://raw.githubusercontent.com/ltdaovn/dataset/master/turtle.csv", delimiter='\t')
df
# Out:
#     length  width  height
# 0       98     81      38
# 1      103     84      38
# 2      103     86      42
# 3      105     86      42
# 4      109     88      44
# 5      123     92      50
# 6      123     95      46
# 7      133     99      51
# 8      133    102      51
# 9      133    102      51
# 10     134    100      48
# 11     136    102      49
# 12     138     98      51
# 13     138     99      51
# 14     141    105      53
# 15     147    108      57
# 16     149    107      55
# 17     153    107      56
# 18     155    115      63
# 19     155    117      60
# 20     158    115      62
# 21     159    118      63
# 22     162    124      61
# 23     177    132      67

# %%
df.describe()
# Out:
#            length       width     height
# count   24.000000   24.000000  24.000000
# mean   136.041667  102.583333  52.041667
# std     21.248998   13.104651   8.045950
# min     98.000000   81.000000  38.000000
# 25%    123.000000   94.250000  47.500000
# 50%    137.000000  102.000000  51.000000
# 75%    153.500000  109.750000  57.750000
# max    177.000000  132.000000  67.000000

# %% [markdown]
# #bước 3a: vẽ scatter plot thể hiện mối tương quan giữa 2 thuộc tính width và height với pandas

# %%
df.plot.scatter(x='width', y='height')

# %% [markdown]
# #bước 3a: vẽ scatter plot thể hiện mối tương quan giữa 2 thuộc tính width và height với matplotlib

# %%
x=df.width
y=df.height
plt.scatter(x,y)

# %% [markdown]
# #bước 4a: Tính ma trận tương quan giữa các biến

# %%
df.corr()
# Out:
#           length     width    height
# length  1.000000  0.973116  0.970675
# width   0.973116  1.000000  0.965903
# height  0.970675  0.965903  1.000000

# %% [markdown]
# #bước 4b: Vẽ ma trận tương quan giữa các biến

# %%
plt.figure(figsize=(6,5))
sns.heatmap(df.corr())
